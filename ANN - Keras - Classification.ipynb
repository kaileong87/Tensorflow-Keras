# %% [markdown]
# # In this project, I'll use a basic ANN with keras to model a cancer classification problem

# %% [markdown]
# ### Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. topic:: References
#
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  benign_0__mal_1
# 0          0.4601                  0.11890                0
# 1          0.2750                  0.08902                0
# 2          0.3613                  0.08758                0
# 3          0.6638                  0.17300                0
# 4          0.2364                  0.07678                0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  benign_0__mal_1          569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# benign_0__mal_1            0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# area error               569.0   40.337079   45.491006    6.802000
# smoothness error         569.0    0.007041    0.003003    0.001713
# compactness error        569.0    0.025478    0.017908    0.002252
# concavity error          569.0    0.031894    0.030186    0.000000
# concave points error     569.0    0.011796    0.006170    0.000000
# symmetry error           569.0    0.020542    0.008266    0.007882
# fractal dimension error  569.0    0.003795    0.002646    0.000895
# worst radius             569.0   16.269190    4.833242    7.930000
# worst texture            569.0   25.677223    6.146258   12.020000
# worst perimeter          569.0  107.261213   33.602542   50.410000
# worst area               569.0  880.583128  569.356993  185.200000
# worst smoothness         569.0    0.132369    0.022832    0.071170
# worst compactness        569.0    0.254265    0.157336    0.027290
# worst concavity          569.0    0.272188    0.208624    0.000000
# worst concave points     569.0    0.114606    0.065732    0.000000
# worst symmetry           569.0    0.290076    0.061867    0.156500
# worst fractal dimension  569.0    0.083946    0.018061    0.055040
# benign_0__mal_1          569.0    0.627417    0.483918    0.000000
#
#                                 25%         50%          75%         max
# mean radius               11.700000   13.370000    15.780000    28.11000
# mean texture              16.170000   18.840000    21.800000    39.28000
# mean perimeter            75.170000   86.240000   104.100000   188.50000
# mean area                420.300000  551.100000   782.700000  2501.00000
# mean smoothness            0.086370    0.095870     0.105300     0.16340
# mean compactness           0.064920    0.092630     0.130400     0.34540
# mean concavity             0.029560    0.061540     0.130700     0.42680
# mean concave points        0.020310    0.033500     0.074000     0.20120
# mean symmetry              0.161900    0.179200     0.195700     0.30400
# mean fractal dimension     0.057700    0.061540     0.066120     0.09744
# radius error               0.232400    0.324200     0.478900     2.87300
# texture error              0.833900    1.108000     1.474000     4.88500
# perimeter error            1.606000    2.287000     3.357000    21.98000
# area error                17.850000   24.530000    45.190000   542.20000
# smoothness error           0.005169    0.006380     0.008146     0.03113
# compactness error          0.013080    0.020450     0.032450     0.13540
# concavity error            0.015090    0.025890     0.042050     0.39600
# concave points error       0.007638    0.010930     0.014710     0.05279
# symmetry error             0.015160    0.018730     0.023480     0.07895
# fractal dimension error    0.002248    0.003187     0.004558     0.02984
# worst radius              13.010000   14.970000    18.790000    36.04000
# worst texture             21.080000   25.410000    29.720000    49.54000
# worst perimeter           84.110000   97.660000   125.400000   251.20000
# worst area               515.300000  686.500000  1084.000000  4254.00000
# worst smoothness           0.116600    0.131300     0.146000     0.22260
# worst compactness          0.147200    0.211900     0.339100     1.05800
# worst concavity            0.114500    0.226700     0.382900     1.25200
# worst concave points       0.064930    0.099930     0.161400     0.29100
# worst symmetry             0.250400    0.282200     0.317900     0.66380
# worst fractal dimension    0.071460    0.080040     0.092080     0.20750
# benign_0__mal_1            0.000000    1.000000     1.000000     1.00000

# %%
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <AxesSubplot:xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()['benign_0__mal_1'].sort_values()
# Out:
# worst concave points      -0.793566
# worst perimeter           -0.782914
# mean concave points       -0.776614
# worst radius              -0.776454
# mean perimeter            -0.742636
# worst area                -0.733825
# mean radius               -0.730029
# mean area                 -0.708984
# mean concavity            -0.696360
# worst concavity           -0.659610
# mean compactness          -0.596534
# worst compactness         -0.590998
# radius error              -0.567134
# perimeter error           -0.556141
# area error                -0.548236
# worst texture             -0.456903
# worst smoothness          -0.421465
# worst symmetry            -0.416294
# mean texture              -0.415185
# concave points error      -0.408042
# mean smoothness           -0.358560
# mean symmetry             -0.330499
# worst fractal dimension   -0.323872
# compactness error         -0.292999
# concavity error           -0.253730
# fractal dimension error   -0.077972
# symmetry error             0.006522
# texture error              0.008303
# mean fractal dimension     0.012838
# smoothness error           0.067016
# benign_0__mal_1            1.000000
# Name: benign_0__mal_1, dtype: float64

# %%
df.corr()['benign_0__mal_1'].sort_values()[:-1].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
len(df)
# Out:
# 569

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('benign_0__mal_1', axis=1)
y = df['benign_0__mal_1']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
scaled_X_train = scaler.transform(X_train)

# %%
scaled_X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout

# %%
model = Sequential()

model.add(Dense(units=30,activation='relu'))
model.add(Dense(units=15,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model.fit(x=scaled_X_train, 
          y=y_train, 
          epochs=600,
          batch_size=256,
          validation_data=(scaled_X_test, y_test), verbose=1,
          callbacks=[stop]
          )
# Out:
# Epoch 1/600
# 13/13 [==============================] - 0s 13ms/step - loss: 0.6852 - val_loss: 0.6719
# Epoch 2/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6646 - val_loss: 0.6463
# Epoch 3/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6406 - val_loss: 0.6140
# Epoch 4/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6073 - val_loss: 0.5642
# Epoch 5/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5558 - val_loss: 0.5023
# Epoch 6/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5002 - val_loss: 0.4431
# Epoch 7/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4483 - val_loss: 0.3926
# Epoch 8/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4019 - val_loss: 0.3508
# Epoch 9/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3639 - val_loss: 0.3164
# Epoch 10/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3314 - val_loss: 0.2878
# Epoch 11/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3076 - val_loss: 0.2648
# Epoch 12/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2838 - val_loss: 0.2454
# Epoch 13/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2640 - val_loss: 0.2306
# Epoch 14/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2529 - val_loss: 0.2161
# Epoch 15/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2392 - val_loss: 0.2042
# Epoch 16/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2238 - val_loss: 0.1942
# Epoch 17/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2132 - val_loss: 0.1843
# Epoch 18/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2030 - val_loss: 0.1752
# Epoch 19/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1953 - val_loss: 0.1676
# Epoch 20/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1859 - val_loss: 0.1600
# Epoch 21/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1790 - val_loss: 0.1526
# Epoch 22/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1712 - val_loss: 0.1473
# Epoch 23/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1634 - val_loss: 0.1390
# Epoch 24/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1575 - val_loss: 0.1329
# Epoch 25/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1515 - val_loss: 0.1264
# Epoch 26/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1493 - val_loss: 0.1216
# Epoch 27/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1401 - val_loss: 0.1167
# Epoch 28/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1347 - val_loss: 0.1120
# Epoch 29/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1297 - val_loss: 0.1077
# Epoch 30/600
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1256 - val_loss: 0.1047
# Epoch 31/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1204 - val_loss: 0.0992
# Epoch 32/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1160 - val_loss: 0.0961
# Epoch 33/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1127 - val_loss: 0.0933
# Epoch 34/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1106 - val_loss: 0.0899
# Epoch 35/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1116 - val_loss: 0.0906
# Epoch 36/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1033 - val_loss: 0.0847
# Epoch 37/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1005 - val_loss: 0.0827
# Epoch 38/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0963 - val_loss: 0.0821
# Epoch 39/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0939 - val_loss: 0.0782
# Epoch 40/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0919 - val_loss: 0.0775
# Epoch 41/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0904 - val_loss: 0.0752
# Epoch 42/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0877 - val_loss: 0.0725
# Epoch 43/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0852 - val_loss: 0.0709
# Epoch 44/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0828 - val_loss: 0.0704
# Epoch 45/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0815 - val_loss: 0.0689
# Epoch 46/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0801 - val_loss: 0.0683
# Epoch 47/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0787 - val_loss: 0.0662
# Epoch 48/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0786 - val_loss: 0.0668
# Epoch 49/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0788 - val_loss: 0.0692
# Epoch 50/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0745 - val_loss: 0.0643
# Epoch 51/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0731 - val_loss: 0.0635
# Epoch 52/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0729 - val_loss: 0.0644
# Epoch 53/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0722 - val_loss: 0.0626
# Epoch 54/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0702 - val_loss: 0.0619
# Epoch 55/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0715 - val_loss: 0.0633
# Epoch 56/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0709 - val_loss: 0.0604
# Epoch 57/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0689 - val_loss: 0.0594
# Epoch 58/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0689 - val_loss: 0.0620
# Epoch 59/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0699 - val_loss: 0.0602
# Epoch 60/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0686 - val_loss: 0.0619
# Epoch 61/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0670 - val_loss: 0.0577
# Epoch 62/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0675 - val_loss: 0.0566
# Epoch 63/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0667 - val_loss: 0.0600
# Epoch 64/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0700 - val_loss: 0.0574
# Epoch 65/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0705 - val_loss: 0.0560
# Epoch 66/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0656 - val_loss: 0.0566
# Epoch 67/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0612 - val_loss: 0.0551
# Epoch 68/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0599 - val_loss: 0.0576
# Epoch 69/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0613 - val_loss: 0.0539
# Epoch 70/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0594 - val_loss: 0.0555
# Epoch 71/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0612 - val_loss: 0.0540
# Epoch 72/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0588 - val_loss: 0.0533
# Epoch 73/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0590 - val_loss: 0.0563
# Epoch 74/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0580 - val_loss: 0.0540
# Epoch 75/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0580 - val_loss: 0.0555
# Epoch 76/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0563 - val_loss: 0.0536
# Epoch 77/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0577 - val_loss: 0.0562
# Epoch 78/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0569 - val_loss: 0.0518
# Epoch 79/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0569 - val_loss: 0.0553
# Epoch 80/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0572 - val_loss: 0.0527
# Epoch 81/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0578 - val_loss: 0.0514
# Epoch 82/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0553 - val_loss: 0.0516
# Epoch 83/600
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0539 - val_loss: 0.0519
# Epoch 84/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0560 - val_loss: 0.0514
# Epoch 85/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0536 - val_loss: 0.0515
# Epoch 86/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0532 - val_loss: 0.0524
# Epoch 87/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0530 - val_loss: 0.0522
# Epoch 88/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0535 - val_loss: 0.0533
# Epoch 89/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0520 - val_loss: 0.0506
# Epoch 90/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0529 - val_loss: 0.0529
# Epoch 91/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0542 - val_loss: 0.0539
# Epoch 92/600
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0555 - val_loss: 0.0511
# Epoch 93/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0536 - val_loss: 0.0526
# Epoch 94/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0552 - val_loss: 0.0507
# Epoch 95/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0544 - val_loss: 0.0554
# Epoch 96/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0509 - val_loss: 0.0498
# Epoch 97/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0497 - val_loss: 0.0530
# Epoch 98/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0523 - val_loss: 0.0514
# Epoch 99/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0497 - val_loss: 0.0501
# Epoch 100/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0491 - val_loss: 0.0535
# Epoch 101/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0512 - val_loss: 0.0493
# Epoch 102/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0517 - val_loss: 0.0518
# Epoch 103/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0490 - val_loss: 0.0519
# Epoch 104/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0480 - val_loss: 0.0483
# Epoch 105/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0499 - val_loss: 0.0521
# Epoch 106/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0487 - val_loss: 0.0500
# Epoch 107/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0478 - val_loss: 0.0488
# Epoch 108/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0478 - val_loss: 0.0507
# Epoch 109/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0479 - val_loss: 0.0520
# Epoch 110/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0468 - val_loss: 0.0498
# Epoch 111/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0500 - val_loss: 0.0523
# Epoch 112/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0466 - val_loss: 0.0499
# Epoch 113/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0459 - val_loss: 0.0521
# Epoch 114/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0461 - val_loss: 0.0501
# Epoch 115/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0467 - val_loss: 0.0498
# Epoch 116/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0474 - val_loss: 0.0479
# Epoch 117/600
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0463 - val_loss: 0.0515
# Epoch 118/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0454 - val_loss: 0.0509
# Epoch 119/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0452 - val_loss: 0.0511
# Epoch 120/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0462 - val_loss: 0.0501
# Epoch 121/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0450 - val_loss: 0.0509
# Epoch 122/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0442 - val_loss: 0.0564
# Epoch 123/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0456 - val_loss: 0.0525
# Epoch 124/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0439 - val_loss: 0.0489
# Epoch 125/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0425 - val_loss: 0.0539
# Epoch 126/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0440 - val_loss: 0.0500
# Epoch 127/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0442 - val_loss: 0.0504
# Epoch 128/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0426 - val_loss: 0.0512
# Epoch 129/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0421 - val_loss: 0.0540
# Epoch 130/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0429 - val_loss: 0.0518
# Epoch 131/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0436 - val_loss: 0.0534
# Epoch 132/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0424 - val_loss: 0.0516
# Epoch 133/600
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0417 - val_loss: 0.0521
# Epoch 134/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0412 - val_loss: 0.0518
# Epoch 135/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0410 - val_loss: 0.0513
# Epoch 136/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0405 - val_loss: 0.0533
# Epoch 137/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0418 - val_loss: 0.0518
# Epoch 138/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0434 - val_loss: 0.0537
# Epoch 139/600
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0404 - val_loss: 0.0514
# Epoch 140/600
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0411 - val_loss: 0.0507
# Epoch 141/600
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0402 - val_loss: 0.0542
# Epoch 00141: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
y_pred = model.predict(scaled_X_test)

# %%
y_pred
# Out:
# array([[8.2026511e-01],
#        [2.2140253e-05],
#        [2.9168662e-04],
#        [9.9997473e-01],
#        [9.9998450e-01],
#        [1.2981296e-09],
#        [1.0401451e-07],
#        [1.1555949e-02],
#        [1.8560611e-01],
#        [9.9962914e-01],
#        [9.5570642e-01],
#        [1.0782825e-03],
#        [9.9838316e-01],
#        [4.9617451e-02],
#        [9.9925560e-01],
#        [6.6568959e-05],
#        [9.9928659e-01],
#        [9.9998927e-01],
#        [9.9999630e-01],
#        [2.4682593e-06],
#        [9.1209310e-01],
#        [9.9464571e-01],
#        [3.8305839e-08],
#        [9.9994266e-01],
#        [9.9976295e-01],
#        [9.9993968e-01],
#        [9.9937338e-01],
#        [9.9725795e-01],
#        [9.9964690e-01],
#        [3.0012911e-06],
#        [9.9982578e-01],
#        [9.9989414e-01],
#        [9.9739599e-01],
#        [9.9916112e-01],
#        [9.9994838e-01],
#        [9.9858969e-01],
#        [3.2154869e-02],
#        [9.9652332e-01],
#        [5.4168922e-05],
#        [9.8484737e-01],
#        [9.9996793e-01],
#        [9.0491725e-05],
#        [9.9842936e-01],
#        [9.9973136e-01],
#        [7.9852569e-01],
#        [9.3248945e-01],
#        [9.9997544e-01],
#        [9.9945205e-01],
#        [9.8373574e-01],
#        [9.9950469e-01],
#        [6.5591303e-05],
#        [1.4470417e-07],
#        [6.9486856e-01],
#        [9.9238199e-01],
#        [9.9999738e-01],
#        [9.7902554e-01],
#        [9.9994862e-01],
#        [4.7911013e-09],
#        [1.8229397e-02],
#        [9.9990571e-01],
#        [9.9901235e-01],
#        [1.3797926e-06],
#        [2.5115025e-07],
#        [9.7762555e-01],
#        [9.9982005e-01],
#        [7.7701426e-01],
#        [3.4122158e-06],
#        [2.1034146e-09],
#        [9.9977189e-01],
#        [9.9289787e-01],
#        [1.1060843e-04],
#        [1.0184968e-04],
#        [9.9921596e-01],
#        [5.1742065e-04],
#        [9.9994957e-01],
#        [9.9537635e-01],
#        [9.9681169e-01],
#        [3.0528462e-01],
#        [9.9991751e-01],
#        [9.7622311e-01],
#        [1.2913813e-03],
#        [9.9995446e-01],
#        [1.0366304e-01],
#        [1.8495399e-07],
#        [1.0688152e-03],
#        [6.8444337e-05],
#        [5.4167872e-06],
#        [6.5937478e-05],
#        [9.9993730e-01],
#        [9.9943227e-01],
#        [9.9787545e-01],
#        [7.9378885e-01],
#        [9.9281317e-01],
#        [9.9986100e-01],
#        [9.9994040e-01],
#        [9.9994946e-01],
#        [3.1172312e-06],
#        [3.8076496e-07],
#        [9.9994922e-01],
#        [9.1602429e-05],
#        [3.6101777e-04],
#        [9.9998856e-01],
#        [5.0757922e-06],
#        [1.5135594e-04],
#        [9.9166846e-01],
#        [8.9713097e-01],
#        [9.9946553e-01],
#        [7.8226670e-08],
#        [8.9236468e-01],
#        [9.6301478e-01],
#        [1.7271822e-04],
#        [9.9942112e-01],
#        [5.1787144e-01],
#        [4.1213264e-09],
#        [7.5174153e-01],
#        [2.3627154e-08],
#        [9.9998939e-01],
#        [9.6899486e-01],
#        [9.9998152e-01],
#        [9.1329566e-06],
#        [9.9998248e-01],
#        [9.9967027e-01],
#        [9.9839765e-01],
#        [4.7220728e-05],
#        [9.3174684e-01],
#        [2.2501276e-06],
#        [4.1982665e-05],
#        [9.9931300e-01],
#        [9.9956089e-01],
#        [2.8020240e-06],
#        [5.8848544e-09],
#        [1.2049593e-06],
#        [9.9494416e-01],
#        [9.9969947e-01],
#        [9.7599834e-01],
#        [9.5629526e-05],
#        [6.6115713e-01],
#        [9.8552483e-01],
#        [7.3801738e-01],
#        [9.7761455e-05],
#        [9.9905056e-01],
#        [4.5906248e-07],
#        [9.9995780e-01],
#        [9.9985874e-01],
#        [9.1280141e-05],
#        [9.9988830e-01],
#        [9.0414596e-06],
#        [5.9847389e-06],
#        [4.2246071e-01],
#        [9.9985087e-01],
#        [1.2869016e-02],
#        [9.9984789e-01],
#        [9.9997115e-01],
#        [9.9295312e-01],
#        [9.9966836e-01],
#        [5.3079052e-11],
#        [4.9670649e-05],
#        [9.9982148e-01],
#        [9.9817646e-01],
#        [9.9996269e-01],
#        [9.9999464e-01],
#        [9.9975854e-01],
#        [9.9991035e-01],
#        [9.9935085e-01],
#        [2.6776159e-02],
#        [9.9977022e-01],
#        [9.9971670e-01],
#        [7.2812217e-01],
#        [9.9999678e-01],
#        [3.0061714e-03],
#        [9.9353808e-01]], dtype=float32)

# %%
y_pred[y_pred <= 0.5] = 0.
y_pred[y_pred > 0.5] = 1.

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        63
#            1       0.99      0.99      0.99       108
#
#     accuracy                           0.99       171
#    macro avg       0.99      0.99      0.99       171
# weighted avg       0.99      0.99      0.99       171

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 62,   1],
#        [  1, 107]], dtype=int64)
